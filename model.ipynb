# %%
from model import Model
from train import Train
from test import Test
import torch
import torch.optim as optim
from data_loader import DataLoader
import utils as ut

train_loader, test_loader = DataLoader().return_loaders()
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
EPOCHS = 20


def train_bn_l1():
    group_norm = False
    layer_norm = False
    model = Model(group_norm, layer_norm).to(device)
    ut.print_model_summary(model)
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
    train = Train()
    test = Test()
    for epoch in range(EPOCHS):
        print("EPOCH:", epoch)
        train.train_model(model, device, train_loader, optimizer, epoch, L1=True)
        test_losses, test_acc, pred, target, data = test.test_model(model, device, test_loader)
    return test_losses, test_acc, pred, target, data


def train_gn():
    group_norm = True
    layer_norm = False
    model = Model(group_norm, layer_norm).to(device)
    ut.print_model_summary(model)
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
    train = Train()
    test = Test()
    for epoch in range(EPOCHS):
        print("EPOCH:", epoch)
        train.train_model(model, device, train_loader, optimizer, epoch, L1=False)
        test_losses, test_acc, pred, target, data = test.test_model(model, device, test_loader)
    return test_losses, test_acc, pred, target, data


def train_ln():
    group_norm = False
    layer_norm = True
    model = Model(group_norm, layer_norm).to(device)
    ut.print_model_summary(model)
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
    train = Train()
    test = Test()
    for epoch in range(EPOCHS):
        print("EPOCH:", epoch)
        train.train_model(model, device, train_loader, optimizer, epoch, L1=False)
        test_losses, test_acc, pred, target, data = test.test_model(model, device, test_loader)
    return test_losses, test_acc, pred, target, data


bn_test_losses, bn_test_acc, bn_pred, bn_target, bn_data = train_bn_l1()
gn_test_losses, gn_test_acc, gn_pred, gn_target, gn_data = train_gn()
ln_test_losses, ln_test_acc, ln_pred, ln_target, ln_data = train_ln()


ut.draw_train_test_acc_loss(bn_test_losses, bn_test_acc, gn_test_losses, gn_test_acc, ln_test_losses, ln_test_acc)
ut.draw_misclassified_images(bn_pred, bn_target, bn_data, "Batch Normalization with L1")
ut.draw_misclassified_images(gn_pred, gn_target, gn_data, "Group Normalization")
ut.draw_misclassified_images(ln_pred, ln_target, ln_data, "Layer Normalization")
# Out:
# CUDA Available True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 10, 26, 26]              90
#               ReLU-2           [-1, 10, 26, 26]               0
#            Dropout-3           [-1, 10, 26, 26]               0
#        BatchNorm2d-4           [-1, 10, 26, 26]              20
#             Conv2d-5           [-1, 10, 24, 24]             900
#               ReLU-6           [-1, 10, 24, 24]               0
#            Dropout-7           [-1, 10, 24, 24]               0
#        BatchNorm2d-8           [-1, 10, 24, 24]              20
#          MaxPool2d-9           [-1, 10, 12, 12]               0
#            Conv2d-10           [-1, 20, 10, 10]           1,800
#              ReLU-11           [-1, 20, 10, 10]               0
#           Dropout-12           [-1, 20, 10, 10]               0
#       BatchNorm2d-13           [-1, 20, 10, 10]              40
#            Conv2d-14           [-1, 10, 10, 10]             200
#              ReLU-15           [-1, 10, 10, 10]               0
#           Dropout-16           [-1, 10, 10, 10]               0
#       BatchNorm2d-17           [-1, 10, 10, 10]              20
#            Conv2d-18             [-1, 10, 8, 8]             900
#              ReLU-19             [-1, 10, 8, 8]               0
#           Dropout-20             [-1, 10, 8, 8]               0
#       BatchNorm2d-21             [-1, 10, 8, 8]              20
#            Conv2d-22             [-1, 20, 6, 6]           1,800
#              ReLU-23             [-1, 20, 6, 6]               0
#           Dropout-24             [-1, 20, 6, 6]               0
#       BatchNorm2d-25             [-1, 20, 6, 6]              40
#            Conv2d-26             [-1, 10, 6, 6]             200
#         AvgPool2d-27             [-1, 10, 1, 1]               0
#            Conv2d-28             [-1, 10, 1, 1]             100
# ================================================================
# Total params: 6,150
# Trainable params: 6,150
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.53
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.56
# ----------------------------------------------------------------
# EPOCH: 0
# Loss=0.10058767348527908 Batch_id = 468 Accuracy = 82.24: 100%|██████████| 469/469 [00:13<00:00, 34.79it/s]
#  Test set: Avergae loss: 0.112228, Accuracy = 58088/60000(96.81%)
#
# EPOCH: 1
# Loss=0.033777061849832535 Batch_id = 468 Accuracy = 96.58: 100%|██████████| 469/469 [00:13<00:00, 34.41it/s]
#  Test set: Avergae loss: 0.073426, Accuracy = 58740/60000(97.90%)
#
# EPOCH: 2
# Loss=0.021836666390299797 Batch_id = 468 Accuracy = 97.65: 100%|██████████| 469/469 [00:13<00:00, 34.47it/s]
#  Test set: Avergae loss: 0.056082, Accuracy = 59000/60000(98.33%)
#
# EPOCH: 3
# Loss=0.06742590665817261 Batch_id = 468 Accuracy = 98.03: 100%|██████████| 469/469 [00:13<00:00, 33.99it/s]
#  Test set: Avergae loss: 0.043872, Accuracy = 59203/60000(98.67%)
#
# EPOCH: 4
# Loss=0.060268208384513855 Batch_id = 468 Accuracy = 98.29: 100%|██████████| 469/469 [00:13<00:00, 33.91it/s]
#  Test set: Avergae loss: 0.034782, Accuracy = 59367/60000(98.94%)
#
# EPOCH: 5
# Loss=0.07140734791755676 Batch_id = 468 Accuracy = 98.43: 100%|██████████| 469/469 [00:13<00:00, 33.68it/s]
#  Test set: Avergae loss: 0.037279, Accuracy = 59328/60000(98.88%)
#
# EPOCH: 6
# Loss=0.034722764045000076 Batch_id = 468 Accuracy = 98.57: 100%|██████████| 469/469 [00:14<00:00, 33.28it/s]
#  Test set: Avergae loss: 0.030530, Accuracy = 59429/60000(99.05%)
#
# EPOCH: 7
# Loss=0.03423136845231056 Batch_id = 468 Accuracy = 98.63: 100%|██████████| 469/469 [00:13<00:00, 34.26it/s]
#  Test set: Avergae loss: 0.029099, Accuracy = 59496/60000(99.16%)
#
# EPOCH: 8
# Loss=0.0332358293235302 Batch_id = 468 Accuracy = 98.78: 100%|██████████| 469/469 [00:13<00:00, 33.71it/s]
#  Test set: Avergae loss: 0.026838, Accuracy = 59500/60000(99.17%)
#
# EPOCH: 9
# Loss=0.02603338100016117 Batch_id = 468 Accuracy = 98.81: 100%|██████████| 469/469 [00:13<00:00, 34.20it/s]
#  Test set: Avergae loss: 0.024423, Accuracy = 59551/60000(99.25%)
#
# EPOCH: 10
# Loss=0.07678229361772537 Batch_id = 468 Accuracy = 98.78: 100%|██████████| 469/469 [00:13<00:00, 34.13it/s]
#  Test set: Avergae loss: 0.023499, Accuracy = 59565/60000(99.28%)
#
# EPOCH: 11
# Loss=0.032221950590610504 Batch_id = 468 Accuracy = 98.92: 100%|██████████| 469/469 [00:13<00:00, 34.31it/s]
#  Test set: Avergae loss: 0.022040, Accuracy = 59608/60000(99.35%)
#
# EPOCH: 12
# Loss=0.014079160988330841 Batch_id = 468 Accuracy = 98.93: 100%|██████████| 469/469 [00:13<00:00, 33.85it/s]
#  Test set: Avergae loss: 0.021844, Accuracy = 59614/60000(99.36%)
#
# EPOCH: 13
# Loss=0.021525507792830467 Batch_id = 468 Accuracy = 98.95: 100%|██████████| 469/469 [00:13<00:00, 34.40it/s]
#  Test set: Avergae loss: 0.023209, Accuracy = 59556/60000(99.26%)
#
# EPOCH: 14
# Loss=0.020994966849684715 Batch_id = 468 Accuracy = 98.98: 100%|██████████| 469/469 [00:13<00:00, 34.58it/s]
#  Test set: Avergae loss: 0.020901, Accuracy = 59591/60000(99.32%)
#
# EPOCH: 15
# Loss=0.11041361838579178 Batch_id = 468 Accuracy = 99.04: 100%|██████████| 469/469 [00:13<00:00, 33.94it/s]
#  Test set: Avergae loss: 0.018077, Accuracy = 59660/60000(99.43%)
#
# EPOCH: 16
# Loss=0.02257573790848255 Batch_id = 468 Accuracy = 99.00: 100%|██████████| 469/469 [00:13<00:00, 34.36it/s]
#  Test set: Avergae loss: 0.018124, Accuracy = 59677/60000(99.46%)
#
# EPOCH: 17
# Loss=0.01950664445757866 Batch_id = 468 Accuracy = 99.09: 100%|██████████| 469/469 [00:13<00:00, 34.05it/s]
#  Test set: Avergae loss: 0.017521, Accuracy = 59672/60000(99.45%)
#
# EPOCH: 18
# Loss=0.05027998983860016 Batch_id = 468 Accuracy = 99.08: 100%|██████████| 469/469 [00:13<00:00, 33.97it/s]
#  Test set: Avergae loss: 0.018760, Accuracy = 59660/60000(99.43%)
#
# EPOCH: 19
# Loss=0.03411133959889412 Batch_id = 468 Accuracy = 99.11: 100%|██████████| 469/469 [00:13<00:00, 34.35it/s]
#  Test set: Avergae loss: 0.014647, Accuracy = 59736/60000(99.56%)
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 10, 26, 26]              90
#               ReLU-2           [-1, 10, 26, 26]               0
#            Dropout-3           [-1, 10, 26, 26]               0
#          GroupNorm-4           [-1, 10, 26, 26]              20
#             Conv2d-5           [-1, 10, 24, 24]             900
#               ReLU-6           [-1, 10, 24, 24]               0
#            Dropout-7           [-1, 10, 24, 24]               0
#          GroupNorm-8           [-1, 10, 24, 24]              20
#          MaxPool2d-9           [-1, 10, 12, 12]               0
#            Conv2d-10           [-1, 20, 10, 10]           1,800
#              ReLU-11           [-1, 20, 10, 10]               0
#           Dropout-12           [-1, 20, 10, 10]               0
#         GroupNorm-13           [-1, 20, 10, 10]              40
#            Conv2d-14           [-1, 10, 10, 10]             200
#              ReLU-15           [-1, 10, 10, 10]               0
#           Dropout-16           [-1, 10, 10, 10]               0
#         GroupNorm-17           [-1, 10, 10, 10]              20
#            Conv2d-18             [-1, 10, 8, 8]             900
#              ReLU-19             [-1, 10, 8, 8]               0
#           Dropout-20             [-1, 10, 8, 8]               0
#         GroupNorm-21             [-1, 10, 8, 8]              20
#            Conv2d-22             [-1, 20, 6, 6]           1,800
#              ReLU-23             [-1, 20, 6, 6]               0
#           Dropout-24             [-1, 20, 6, 6]               0
#         GroupNorm-25             [-1, 20, 6, 6]              40
#            Conv2d-26             [-1, 10, 6, 6]             200
#         AvgPool2d-27             [-1, 10, 1, 1]               0
#            Conv2d-28             [-1, 10, 1, 1]             100
# ================================================================
# Total params: 6,150
# Trainable params: 6,150
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.53
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.56
# ----------------------------------------------------------------
# EPOCH: 0
# Loss=0.2150297611951828 Batch_id = 468 Accuracy = 80.85: 100%|██████████| 469/469 [00:13<00:00, 36.04it/s]
#  Test set: Avergae loss: 0.116621, Accuracy = 57911/60000(96.52%)
#
# EPOCH: 1
# Loss=0.07101187855005264 Batch_id = 468 Accuracy = 96.85: 100%|██████████| 469/469 [00:13<00:00, 36.00it/s]
#  Test set: Avergae loss: 0.065439, Accuracy = 58761/60000(97.94%)
#
# EPOCH: 2
# Loss=0.10560604184865952 Batch_id = 468 Accuracy = 97.59: 100%|██████████| 469/469 [00:13<00:00, 35.90it/s]
#  Test set: Avergae loss: 0.048855, Accuracy = 59131/60000(98.55%)
#
# EPOCH: 3
# Loss=0.11790609359741211 Batch_id = 468 Accuracy = 98.06: 100%|██████████| 469/469 [00:12<00:00, 36.57it/s]
#  Test set: Avergae loss: 0.046152, Accuracy = 59152/60000(98.59%)
#
# EPOCH: 4
# Loss=0.005548980552703142 Batch_id = 468 Accuracy = 98.25: 100%|██████████| 469/469 [00:13<00:00, 36.01it/s]
#  Test set: Avergae loss: 0.034397, Accuracy = 59390/60000(98.98%)
#
# EPOCH: 5
# Loss=0.0462760329246521 Batch_id = 468 Accuracy = 98.47: 100%|██████████| 469/469 [00:13<00:00, 35.32it/s]
#  Test set: Avergae loss: 0.034469, Accuracy = 59385/60000(98.97%)
#
# EPOCH: 6
# Loss=0.06473784148693085 Batch_id = 468 Accuracy = 98.53: 100%|██████████| 469/469 [00:13<00:00, 35.87it/s]
#  Test set: Avergae loss: 0.035311, Accuracy = 59320/60000(98.87%)
#
# EPOCH: 7
# Loss=0.07113436609506607 Batch_id = 468 Accuracy = 98.63: 100%|██████████| 469/469 [00:12<00:00, 36.22it/s]
#  Test set: Avergae loss: 0.028721, Accuracy = 59483/60000(99.14%)
#
# EPOCH: 8
# Loss=0.022428736090660095 Batch_id = 468 Accuracy = 98.66: 100%|██████████| 469/469 [00:12<00:00, 36.22it/s]
#  Test set: Avergae loss: 0.027863, Accuracy = 59459/60000(99.10%)
#
# EPOCH: 9
# Loss=0.010246973484754562 Batch_id = 468 Accuracy = 98.75: 100%|██████████| 469/469 [00:12<00:00, 36.31it/s]
#  Test set: Avergae loss: 0.027832, Accuracy = 59465/60000(99.11%)
#
# EPOCH: 10
# Loss=0.007494209334254265 Batch_id = 468 Accuracy = 98.75: 100%|██████████| 469/469 [00:12<00:00, 36.79it/s]
#  Test set: Avergae loss: 0.026654, Accuracy = 59511/60000(99.19%)
#
# EPOCH: 11
# Loss=0.09944877028465271 Batch_id = 468 Accuracy = 98.81: 100%|██████████| 469/469 [00:12<00:00, 36.61it/s]
#  Test set: Avergae loss: 0.023662, Accuracy = 59529/60000(99.22%)
#
# EPOCH: 12
# Loss=0.01799463853240013 Batch_id = 468 Accuracy = 98.86: 100%|██████████| 469/469 [00:13<00:00, 35.93it/s]
#  Test set: Avergae loss: 0.027047, Accuracy = 59483/60000(99.14%)
#
# EPOCH: 13
# Loss=0.05508236959576607 Batch_id = 468 Accuracy = 98.90: 100%|██████████| 469/469 [00:12<00:00, 36.11it/s]
#  Test set: Avergae loss: 0.023197, Accuracy = 59558/60000(99.26%)
#
# EPOCH: 14
# Loss=0.016700943931937218 Batch_id = 468 Accuracy = 99.00: 100%|██████████| 469/469 [00:12<00:00, 36.15it/s]
#  Test set: Avergae loss: 0.020701, Accuracy = 59594/60000(99.32%)
#
# EPOCH: 15
# Loss=0.013270039111375809 Batch_id = 468 Accuracy = 98.95: 100%|██████████| 469/469 [00:12<00:00, 36.41it/s]
#  Test set: Avergae loss: 0.018330, Accuracy = 59669/60000(99.45%)
#
# EPOCH: 16
# Loss=0.04012489318847656 Batch_id = 468 Accuracy = 98.94: 100%|██████████| 469/469 [00:13<00:00, 35.80it/s]
#  Test set: Avergae loss: 0.018930, Accuracy = 59649/60000(99.42%)
#
# EPOCH: 17
# Loss=0.1027040109038353 Batch_id = 468 Accuracy = 98.98: 100%|██████████| 469/469 [00:13<00:00, 35.96it/s]
#  Test set: Avergae loss: 0.019526, Accuracy = 59636/60000(99.39%)
#
# EPOCH: 18
# Loss=0.025680111721158028 Batch_id = 468 Accuracy = 99.08: 100%|██████████| 469/469 [00:12<00:00, 36.62it/s]
#  Test set: Avergae loss: 0.020539, Accuracy = 59610/60000(99.35%)
#
# EPOCH: 19
# Loss=0.017932545393705368 Batch_id = 468 Accuracy = 98.99: 100%|██████████| 469/469 [00:12<00:00, 36.42it/s]
#  Test set: Avergae loss: 0.017006, Accuracy = 59680/60000(99.47%)
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 10, 26, 26]              90
#               ReLU-2           [-1, 10, 26, 26]               0
#            Dropout-3           [-1, 10, 26, 26]               0
#          GroupNorm-4           [-1, 10, 26, 26]              20
#             Conv2d-5           [-1, 10, 24, 24]             900
#               ReLU-6           [-1, 10, 24, 24]               0
#            Dropout-7           [-1, 10, 24, 24]               0
#          GroupNorm-8           [-1, 10, 24, 24]              20
#          MaxPool2d-9           [-1, 10, 12, 12]               0
#            Conv2d-10           [-1, 20, 10, 10]           1,800
#              ReLU-11           [-1, 20, 10, 10]               0
#           Dropout-12           [-1, 20, 10, 10]               0
#         GroupNorm-13           [-1, 20, 10, 10]              40
#            Conv2d-14           [-1, 10, 10, 10]             200
#              ReLU-15           [-1, 10, 10, 10]               0
#           Dropout-16           [-1, 10, 10, 10]               0
#         GroupNorm-17           [-1, 10, 10, 10]              20
#            Conv2d-18             [-1, 10, 8, 8]             900
#              ReLU-19             [-1, 10, 8, 8]               0
#           Dropout-20             [-1, 10, 8, 8]               0
#         GroupNorm-21             [-1, 10, 8, 8]              20
#            Conv2d-22             [-1, 20, 6, 6]           1,800
#              ReLU-23             [-1, 20, 6, 6]               0
#           Dropout-24             [-1, 20, 6, 6]               0
#         GroupNorm-25             [-1, 20, 6, 6]              40
#            Conv2d-26             [-1, 10, 6, 6]             200
#         AvgPool2d-27             [-1, 10, 1, 1]               0
#            Conv2d-28             [-1, 10, 1, 1]             100
# ================================================================
# Total params: 6,150
# Trainable params: 6,150
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.53
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.56
# ----------------------------------------------------------------
# EPOCH: 0
# Loss=0.17468209564685822 Batch_id = 468 Accuracy = 83.02: 100%|██████████| 469/469 [00:13<00:00, 35.82it/s]
#  Test set: Avergae loss: 0.097608, Accuracy = 58319/60000(97.20%)
#
# EPOCH: 1
# Loss=0.022585280239582062 Batch_id = 468 Accuracy = 96.95: 100%|██████████| 469/469 [00:13<00:00, 35.74it/s]
#  Test set: Avergae loss: 0.062776, Accuracy = 58876/60000(98.13%)
#
# EPOCH: 2
# Loss=0.018188219517469406 Batch_id = 468 Accuracy = 97.86: 100%|██████████| 469/469 [00:13<00:00, 36.05it/s]
#  Test set: Avergae loss: 0.055517, Accuracy = 58969/60000(98.28%)
#
# EPOCH: 3
# Loss=0.04069811478257179 Batch_id = 468 Accuracy = 98.17: 100%|██████████| 469/469 [00:12<00:00, 36.40it/s]
#  Test set: Avergae loss: 0.042935, Accuracy = 59253/60000(98.75%)
#
# EPOCH: 4
# Loss=0.030871093273162842 Batch_id = 468 Accuracy = 98.32: 100%|██████████| 469/469 [00:13<00:00, 35.89it/s]
#  Test set: Avergae loss: 0.034512, Accuracy = 59395/60000(98.99%)
#
# EPOCH: 5
# Loss=0.0047070481814444065 Batch_id = 468 Accuracy = 98.52: 100%|██████████| 469/469 [00:13<00:00, 35.46it/s]
#  Test set: Avergae loss: 0.031448, Accuracy = 59461/60000(99.10%)
#
# EPOCH: 6
# Loss=0.012887801043689251 Batch_id = 468 Accuracy = 98.57: 100%|██████████| 469/469 [00:13<00:00, 35.89it/s]
#  Test set: Avergae loss: 0.032171, Accuracy = 59417/60000(99.03%)
#
# EPOCH: 7
# Loss=0.05636921525001526 Batch_id = 468 Accuracy = 98.69: 100%|██████████| 469/469 [00:13<00:00, 35.81it/s]
#  Test set: Avergae loss: 0.029240, Accuracy = 59474/60000(99.12%)
#
# EPOCH: 8
# Loss=0.02005971223115921 Batch_id = 468 Accuracy = 98.70: 100%|██████████| 469/469 [00:13<00:00, 35.97it/s]
#  Test set: Avergae loss: 0.028524, Accuracy = 59468/60000(99.11%)
#
# EPOCH: 9
# Loss=0.09068011492490768 Batch_id = 468 Accuracy = 98.77: 100%|██████████| 469/469 [00:13<00:00, 35.42it/s]
#  Test set: Avergae loss: 0.024390, Accuracy = 59557/60000(99.26%)
#
# EPOCH: 10
# Loss=0.024801962077617645 Batch_id = 468 Accuracy = 98.88: 100%|██████████| 469/469 [00:13<00:00, 35.38it/s]
#  Test set: Avergae loss: 0.025447, Accuracy = 59528/60000(99.21%)
#
# EPOCH: 11
# Loss=0.009967022575438023 Batch_id = 468 Accuracy = 98.81: 100%|██████████| 469/469 [00:13<00:00, 35.76it/s]
#  Test set: Avergae loss: 0.026128, Accuracy = 59519/60000(99.20%)
#
# EPOCH: 12
# Loss=0.007155508268624544 Batch_id = 468 Accuracy = 98.89: 100%|██████████| 469/469 [00:12<00:00, 36.35it/s]
#  Test set: Avergae loss: 0.022897, Accuracy = 59584/60000(99.31%)
#
# EPOCH: 13
# Loss=0.04004558548331261 Batch_id = 468 Accuracy = 98.92: 100%|██████████| 469/469 [00:12<00:00, 36.55it/s]
#  Test set: Avergae loss: 0.021834, Accuracy = 59598/60000(99.33%)
#
# EPOCH: 14
# Loss=0.12003763765096664 Batch_id = 468 Accuracy = 99.03: 100%|██████████| 469/469 [00:12<00:00, 36.43it/s]
#  Test set: Avergae loss: 0.019092, Accuracy = 59667/60000(99.44%)
#
# EPOCH: 15
# Loss=0.02682417631149292 Batch_id = 468 Accuracy = 98.98: 100%|██████████| 469/469 [00:12<00:00, 36.90it/s]
#  Test set: Avergae loss: 0.018322, Accuracy = 59659/60000(99.43%)
#
# EPOCH: 16
# Loss=0.034610845148563385 Batch_id = 468 Accuracy = 99.06: 100%|██████████| 469/469 [00:12<00:00, 36.50it/s]
#  Test set: Avergae loss: 0.018368, Accuracy = 59672/60000(99.45%)
#
# EPOCH: 17
# Loss=0.010578575544059277 Batch_id = 468 Accuracy = 99.05: 100%|██████████| 469/469 [00:12<00:00, 36.47it/s]
#  Test set: Avergae loss: 0.018673, Accuracy = 59660/60000(99.43%)
#
# EPOCH: 18
# Loss=0.04358603432774544 Batch_id = 468 Accuracy = 99.14: 100%|██████████| 469/469 [00:13<00:00, 36.01it/s]
#  Test set: Avergae loss: 0.018268, Accuracy = 59657/60000(99.43%)
#
# EPOCH: 19
# Loss=0.02739628404378891 Batch_id = 468 Accuracy = 99.12: 100%|██████████| 469/469 [00:12<00:00, 36.33it/s]
#  Test set: Avergae loss: 0.016874, Accuracy = 59706/60000(99.51%)
